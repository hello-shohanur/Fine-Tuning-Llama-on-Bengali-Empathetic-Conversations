# %% [markdown]
# # 01 - Data Preprocessing\nThis notebook loads and preprocesses the Bengali Empathetic Conversations dataset.

# %%
from src.dataset_processor import DatasetProcessor\nimport pandas as pd\ndf = pd.DataFrame({'context':['আমি খুব দুঃখিত।'],'response':['আমি দুঃখিত শুনে।']})\ndp = DatasetProcessor()\nsamples = dp.to_instruction_format(df)\nprint(samples[:1])
